# %%
from pprint import pprint
from matplotlib import pyplot as plt

data = """1 1
0.995609 0.996
0.990436 0.991216
0.984486 0.985651
0.977761 0.979309
0.970265 0.972191
0.962 0.964303
0.95297 0.955645
0.943177 0.946223
0.932626 0.936038
0.921317 0.925094
0.909256 0.913393
0.896444 0.90094
0.882886 0.887736
0.868582 0.873785
0.853538 0.85909
0.837755 0.843654
0.821237 0.827479
0.803986 0.810569
0.786006 0.792927
0.767299 0.774555
0.747868 0.755457
0.727717 0.735635
0.706848 0.715092
0.685263 0.693832
0.662967 0.671857
0.63996 0.649169
0.616248 0.625773
0.591831 0.60167
0.566714 0.576863
0.540899 0.551355
0.514388 0.52515
0.487184 0.498249
0.459291 0.470656
0.430711 0.442374
0.401446 0.413404
0.3715 0.383751
0.340875 0.353416
0.309574 0.322402
0.2776 0.290712
0.244954 0.25835
0.211641 0.225316
0.177662 0.191615
0.143021 0.157248
0.107719 0.122219
0.0717596 0.0865306
0.0351456 0.0501844
-0.00212065 0.0131837
-0.0400366 -0.024469
-0.0785995 -0.0627712
-0.117807 -0.10172
"""

# %%
temp  = data
temp = temp.split("\n")
# pprint(temp)
print(len(temp))
# Out:
# 52

# %%
u = []
y = []
x = []

delta = 0.02

for i in range(len(temp)-1):
    u1, y1 = temp[i].split()
    # print(u1, y1)
    # print(type(u1))
    
    u.append(float(u1))
    y.append(float(y1))
    x.append(i * delta)

    
# print("----")
# pprint(u)
print(len(u))
# Out:
# 51

# %%
print(len(x))

plt.figure(figsize = (16, 16))
plt.plot(x, u, label='analytics')
plt.plot(x, y, label = 'calculus')
plt.legend()

plt.show()
# Out:
# 51
